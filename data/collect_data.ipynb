# %%
# !pip install pandas-datareader
# !pip install pandas
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip

# %%
from datetime import date
from pandas_datareader import data
import numpy as np
import pandas as pd

# %%
def download_stock_list(stock_list):
    for stock in stock_list:
        try:
            df = data.DataReader(stock.strip(),data_source='yahoo', start='01-01-2007', end="04-09-2021")
            df = df.astype(np.double)
            df.to_csv(f"price_data/{stock}.csv")
            print(f"Processed: {stock}")
        except:
            print(f"Failed to process: {stock}")

# %%
import re 

def get_stock_list():
    with open('stock_list/nasdaqlisted.txt', 'r') as f:
        nasdaqlisted = f.read()
    with open('stock_list/otherlisted.txt', 'r') as f:
        otherlisted = f.read()
    regex = r"" # TODO: Parse files
    nasdaq_list = re.findall(regex,nasdaqlisted)
    # TODO: Filter the ones not in S&P 500 (need to find a list of stocks in S&P)
    return []

# %%
stock_list = pd.read_csv("stock_list/s&p500.txt")
stock_list = stock_list["Symbol"].to_list()
print(stock_list)
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'AYI', 'ADBE', 'AAP', 'AMD', 'AES', 'AET', 'AMG', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'APC', 'ADI', 'ANDV', 'ANSS', 'ANTM', 'AON', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ARNC', 'AJG', 'AIZ', 'T', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BHGE', 'BLL', 'BAC', 'BAX', 'BBT', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'HRB', 'BA', 'BWA', 'BXP', 'BSX', 'BHF', 'BMY', 'AVGO', 'BF.B', 'CHRW', 'CA', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CBG', 'CBS', 'CELG', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CHK', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'GLW', 'COST', 'COTY', 'CCI', 'CSRA', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DOV', 'DWDP', 'DPS', 'DTE', 'DUK', 'DRE', 'DXC', 'ETFC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ETR', 'EVHC', 'EOG', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'RE', 'ES', 'EXC', 'EXPE', 'EXPD', 'ESRX', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FISV', 'FLIR', 'FLS', 'FLR', 'FMC', 'FL', 'F', 'FTV', 'FBHS', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GGP', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GS', 'GT', 'GWW', 'HAL', 'HBI', 'HOG', 'HRS', 'HIG', 'HAS', 'HCA', 'HCP', 'HP', 'HSIC', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HPQ', 'HUM', 'HBAN', 'HII', 'IDXX', 'INFO', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IBM', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IQV', 'IRM', 'JBHT', 'JEC', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KMB', 'KIM', 'KMI', 'KLAC', 'KSS', 'KHC', 'KR', 'LB', 'LLL', 'LH', 'LRCX', 'LEG', 'LEN', 'LUK', 'LLY', 'LNC', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MAC', 'M', 'MRO', 'MPC', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MAT', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'KORS', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MON', 'MNST', 'MCO', 'MS', 'MSI', 'MYL', 'NDAQ', 'NOV', 'NAVI', 'NTAP', 'NFLX', 'NWL', 'NFX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NBL', 'JWN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'ORLY', 'OXY', 'OMC', 'OKE', 'ORCL', 'PCAR', 'PKG', 'PH', 'PDCO', 'PAYX', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'RL', 'PPG', 'PPL', 'PX', 'PCLN', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'QCOM', 'PWR', 'DGX', 'RRC', 'RJF', 'RTN', 'O', 'RHT', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'COL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SCG', 'SLB', 'SNI', 'STX', 'SEE', 'SRE', 'SHW', 'SIG', 'SPG', 'SWKS', 'SLG', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'SRCL', 'SYK', 'STI', 'SYMC', 'SYF', 'SNPS', 'SYY', 'TROW', 'TPR', 'TGT', 'TEL', 'FTI', 'TXN', 'TXT', 'BK', 'CLX', 'COO', 'HSY', 'MOS', 'TRV', 'DIS', 'TMO', 'TIF', 'TWX', 'TJX', 'TMK', 'TSS', 'TSCO', 'TDG', 'TRIP', 'FOXA', 'FOX', 'TSN', 'USB', 'UDR', 'ULTA', 'UAA', 'UA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UTX', 'UHS', 'UNM', 'VFC', 'VLO', 'VAR', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VIAB', 'V', 'VNO', 'VMC', 'WMT', 'WBA', 'WM', 'WAT', 'WEC', 'WFC', 'HCN', 'WDC', 'WU', 'WRK', 'WY', 'WHR', 'WMB', 'WLTW', 'WYN', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XL', 'XYL', 'YUM', 'ZBH', 'ZION', 'ZTS']

# %%
download_stock_list(['GME', "TSLA", 'QQQ', 'SPY', "ARKK", "ARKG", 'NVDA', 'AMD', 'GOOGL', 'GM', 'F', 'AAPL'], )
# Out:
# Processed: MMM
# Processed: AOS
# Processed: ABT
# Processed: ABBV
# Processed: ACN
# Processed: ATVI
# Processed: AYI
# Processed: ADBE
# Processed: AAP
# Processed: AMD
# Processed: AES
# Processed: AET
# Processed: AMG
# Processed: AFL
# Processed: A
# Processed: APD
# Processed: AKAM
# Processed: ALK
# Processed: ALB
# Processed: ARE
# Processed: ALXN
# Processed: ALGN
# Processed: ALLE
# Failed to process: AGN
# Processed: ADS
# Processed: LNT
# Processed: ALL
# Processed: GOOGL
# Processed: GOOG
# Processed: MO
# Processed: AMZN
# Processed: AEE
# Processed: AAL
# Processed: AEP
# Processed: AXP
# Processed: AIG
# Processed: AMT
# Processed: AWK
# Processed: AMP
# Processed: ABC
# Processed: AME
# Processed: AMGN
# Processed: APH
# Failed to process: APC
# Processed: ADI
# Processed: ANDV
# Processed: ANSS
# Processed: ANTM
# Processed: AON
# Processed: APA
# Processed: AIV
# Processed: AAPL
# Processed: AMAT
# Processed: APTV
# Processed: ADM
# Processed: ARNC
# Processed: AJG
# Processed: AIZ
# Processed: T
# Processed: ADSK
# Processed: ADP
# Processed: AZO
# Processed: AVB
# Processed: AVY
# Failed to process: BHGE
# Processed: BLL
# Processed: BAC
# Processed: BAX
# Failed to process: BBT
# Processed: BDX
# Failed to process: BRK.B
# Processed: BBY
# Processed: BIIB
# Processed: BLK
# Processed: HRB
# Processed: BA
# Processed: BWA
# Processed: BXP
# Processed: BSX
# Processed: BHF
# Processed: BMY
# Processed: AVGO
# Failed to process: BF.B
# Processed: CHRW
# Processed: CA
# Processed: COG
# Processed: CDNS
# Processed: CPB
# Processed: COF
# Processed: CAH
# Processed: KMX
# Processed: CCL
# Processed: CAT
# Processed: CBOE
# Failed to process: CBG
# Failed to process: CBS
# Failed to process: CELG
# Processed: CNC
# Processed: CNP
# Failed to process: CTL
# Processed: CERN
# Processed: CF
# Processed: SCHW
# Processed: CHTR
# Processed: CHK
# Processed: CVX
# Processed: CMG
# Processed: CB
# Processed: CHD
# Processed: CI
# Processed: XEC
# Processed: CINF
# Processed: CTAS
# Processed: CSCO
# Processed: C
# Processed: CFG
# Processed: CTXS
# Processed: CME
# Processed: CMS
# Processed: KO
# Processed: CTSH
# Processed: CL
# Processed: CMCSA
# Processed: CMA
# Processed: CAG
# Failed to process: CXO
# Processed: COP
# Processed: ED
# Processed: STZ
# Processed: GLW
# Processed: COST
# Processed: COTY
# Processed: CCI
# Processed: CSRA
# Processed: CSX
# Processed: CMI
# Processed: CVS
# Processed: DHI
# Processed: DHR
# Processed: DRI
# Processed: DVA
# Processed: DE
# Processed: DAL
# Processed: XRAY
# Processed: DVN
# Processed: DLR
# Processed: DFS
# Processed: DISCA
# Processed: DISCK
# Processed: DISH
# Processed: DG
# Processed: DLTR
# Processed: D
# Processed: DOV
# Failed to process: DWDP
# Failed to process: DPS
# Processed: DTE
# Processed: DUK
# Processed: DRE
# Processed: DXC
# Failed to process: ETFC
# Processed: EMN
# Processed: ETN
# Processed: EBAY
# Processed: ECL
# Processed: EIX
# Processed: EW
# Processed: EA
# Processed: EMR
# Processed: ETR
# Processed: EVHC
# Processed: EOG
# Processed: EQT
# Processed: EFX
# Processed: EQIX
# Processed: EQR
# Processed: ESS
# Processed: EL
# Processed: RE
# Processed: ES
# Processed: EXC
# Processed: EXPE
# Processed: EXPD
# Processed: ESRX
# Processed: EXR
# Processed: XOM
# Processed: FFIV
# Processed: FB
# Processed: FAST
# Processed: FRT
# Processed: FDX
# Processed: FIS
# Processed: FITB
# Processed: FE
# Processed: FISV
# Processed: FLIR
# Processed: FLS
# Processed: FLR
# Processed: FMC
# Processed: FL
# Processed: F
# Processed: FTV
# Processed: FBHS
# Processed: BEN
# Processed: FCX
# Processed: GPS
# Processed: GRMN
# Processed: IT
# Processed: GD
# Processed: GE
# Failed to process: GGP
# Processed: GIS
# Processed: GM
# Processed: GPC
# Processed: GILD
# Processed: GPN
# Processed: GS
# Processed: GT
# Processed: GWW
# Processed: HAL
# Processed: HBI
# Processed: HOG
# Failed to process: HRS
# Processed: HIG
# Processed: HAS
# Processed: HCA
# Failed to process: HCP
# Processed: HP
# Processed: HSIC
# Processed: HES
# Processed: HPE
# Processed: HLT
# Processed: HOLX
# Processed: HD
# Processed: HON
# Processed: HRL
# Processed: HST
# Processed: HPQ
# Processed: HUM
# Processed: HBAN
# Processed: HII
# Processed: IDXX
# Processed: INFO
# Processed: ITW
# Processed: ILMN
# Processed: INCY
# Processed: IR
# Processed: INTC
# Processed: ICE
# Processed: IBM
# Processed: IP
# Processed: IPG
# Processed: IFF
# Processed: INTU
# Processed: ISRG
# Processed: IVZ
# Processed: IQV
# Processed: IRM
# Processed: JBHT
# Failed to process: JEC
# Processed: SJM
# Processed: JNJ
# Processed: JCI
# Processed: JPM
# Processed: JNPR
# Processed: KSU
# Processed: K
# Processed: KEY
# Processed: KMB
# Processed: KIM
# Processed: KMI
# Processed: KLAC
# Processed: KSS
# Processed: KHC
# Processed: KR
# Processed: LB
# Failed to process: LLL
# Processed: LH
# Processed: LRCX
# Processed: LEG
# Processed: LEN
# Failed to process: LUK
# Processed: LLY
# Processed: LNC
# Processed: LKQ
# Processed: LMT
# Processed: L
# Processed: LOW
# Processed: LYB
# Processed: MTB
# Processed: MAC
# Processed: M
# Processed: MRO
# Processed: MPC
# Processed: MAR
# Processed: MMC
# Processed: MLM
# Processed: MAS
# Processed: MA
# Processed: MAT
# Processed: MKC
# Processed: MCD
# Processed: MCK
# Processed: MDT
# Processed: MRK
# Processed: MET
# Processed: MTD
# Processed: MGM
# Failed to process: KORS
# Processed: MCHP
# Processed: MU
# Processed: MSFT
# Processed: MAA
# Processed: MHK
# Processed: TAP
# Processed: MDLZ
# Processed: MON
# Processed: MNST
# Processed: MCO
# Processed: MS
# Processed: MSI
# Failed to process: MYL
# Processed: NDAQ
# Processed: NOV
# Processed: NAVI
# Processed: NTAP
# Processed: NFLX
# Processed: NWL
# Processed: NFX
# Processed: NEM
# Processed: NWSA
# Processed: NWS
# Processed: NEE
# Processed: NLSN
# Processed: NKE
# Processed: NI
# Failed to process: NBL
# Processed: JWN
# Processed: NSC
# Processed: NTRS
# Processed: NOC
# Processed: NCLH
# Processed: NRG
# Processed: NUE
# Processed: NVDA
# Processed: ORLY
# Processed: OXY
# Processed: OMC
# Processed: OKE
# Processed: ORCL
# Processed: PCAR
# Processed: PKG
# Processed: PH
# Processed: PDCO
# Processed: PAYX
# Processed: PYPL
# Processed: PNR
# Processed: PBCT
# Processed: PEP
# Processed: PKI
# Processed: PRGO
# Processed: PFE
# Processed: PCG
# Processed: PM
# Processed: PSX
# Processed: PNW
# Processed: PXD
# Processed: PNC
# Processed: RL
# Processed: PPG
# Processed: PPL
# Processed: PX
# Failed to process: PCLN
# Processed: PFG
# Processed: PG
# Processed: PGR
# Processed: PLD
# Processed: PRU
# Processed: PEG
# Processed: PSA
# Processed: PHM
# Processed: PVH
# Processed: QRVO
# Processed: QCOM
# Processed: PWR
# Processed: DGX
# Processed: RRC
# Processed: RJF
# Failed to process: RTN
# Processed: O
# Failed to process: RHT
# Processed: REG
# Processed: REGN
# Processed: RF
# Processed: RSG
# Processed: RMD
# Processed: RHI
# Processed: ROK
# Processed: COL
# Processed: ROP
# Processed: ROST
# Processed: RCL
# Processed: SPGI
# Processed: CRM
# Processed: SBAC
# Processed: SCG
# Processed: SLB
# Processed: SNI
# Processed: STX
# Processed: SEE
# Processed: SRE
# Processed: SHW
# Processed: SIG
# Processed: SPG
# Processed: SWKS
# Processed: SLG
# Processed: SNA
# Processed: SO
# Processed: LUV
# Processed: SWK
# Failed to process: SBUX
# Processed: STT
# Processed: SRCL
# Processed: SYK
# Failed to process: STI
# Failed to process: SYMC
# Processed: SYF
# Processed: SNPS
# Processed: SYY
# Processed: TROW
# Processed: TPR
# Processed: TGT
# Processed: TEL
# Processed: FTI
# Processed: TXN
# Processed: TXT
# Processed: BK
# Processed: CLX
# Processed: COO
# Processed: HSY
# Processed: MOS
# Processed: TRV
# Processed: DIS
# Processed: TMO
# Failed to process: TIF
# Processed: TWX
# Processed: TJX
# Failed to process: TMK
# Failed to process: TSS
# Processed: TSCO
# Processed: TDG
# Processed: TRIP
# Processed: FOXA
# Failed to process: FOX
# Processed: TSN
# Processed: USB
# Processed: UDR
# Processed: ULTA
# Processed: UAA
# Processed: UA
# Processed: UNP
# Processed: UAL
# Processed: UNH
# Processed: UPS
# Processed: URI
# Failed to process: UTX
# Processed: UHS
# Processed: UNM
# Processed: VFC
# Processed: VLO
# Processed: VAR
# Processed: VTR
# Processed: VRSN
# Processed: VRSK
# Processed: VZ
# Processed: VRTX
# Failed to process: VIAB
# Processed: V
# Processed: VNO
# Processed: VMC
# Processed: WMT
# Processed: WBA
# Processed: WM
# Processed: WAT
# Processed: WEC
# Processed: WFC
# Failed to process: HCN
# Processed: WDC
# Processed: WU
# Failed to process: WRK
# Failed to process: WY
# Processed: WHR
# Processed: WMB
# Processed: WLTW
# Failed to process: WYN
# Processed: WYNN
# Processed: XEL
# Processed: XRX
# Processed: XLNX
# Processed: XL
# Processed: XYL
# Processed: YUM
# Processed: ZBH
# Processed: ZION
# Processed: ZTS
# Processed: GME
# Processed: TSLA
